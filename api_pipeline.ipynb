# %% [markdown]
# ## Apex wealth Data Pipeline

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\mumba\anaconda3\lib\site-packages (2.32.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mumba\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mumba\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mumba\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mumba\anaconda3\lib\site-packages (from requests) (2025.10.5)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\mumba\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mumba\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mumba\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mumba\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mumba\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mumba\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os

# %%
load_dotenv()
api_key = os.getenv('API_KEY')

# %%
api_key
# Out:
# '4890cae03d3b43bb8d3631416257da2d'

# %%
symbols = "AAPL"
url = f"https://api.twelvedata.com/time_series?symbol={symbols}&interval=1min&apikey={api_key}&outputsize=5"

# %%
# Get response from the API
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# get data in json format
from pprint import pprint
data = response.json()
pprint(data)
# Out:
# {'meta': {'currency': 'USD',
#           'exchange': 'NASDAQ',
#           'exchange_timezone': 'America/New_York',
#           'interval': '1min',
#           'mic_code': 'XNGS',
#           'symbol': 'AAPL',
#           'type': 'Common Stock'},
#  'status': 'ok',
#  'values': [{'close': '256.705',
#              'datetime': '2026-01-28 15:59:00',
#              'high': '256.84',
#              'low': '256.67',
#              'open': '256.83',
#              'volume': '40964'},
#             {'close': '256.8',
#              'datetime': '2026-01-28 15:58:00',
#              'high': '256.84',
#              'low': '256.75',
#              'open': '256.82',
#              'volume': '29319'},
#             {'close': '256.84',
#              'datetime': '2026-01-28 15:57:00',
#              'high': '256.865',
#              'low': '256.7',
#              'open': '256.7',
#              'volume': '41873'},
#             {'close': '256.7',
#              'datetime': '2026-01-28 15:56:00',
#              'high': '256.89',
#              'low': '256.7',
#              'open': '256.82',
#              'volume': '41244'},
#             {'close': '256.845',
#              'datetime': '2026-01-28 15:55:00',
#              'high': '256.85',
#              'low': '256.57',
#              'open': '256.84',
#              'volume': '45419'}]}

# %%
data['values'][0] ['high'] # Boana
# Out:
# '256.84'

# %%
values = data ['values'] # Chinwendu
first_item = values[0]
high_price = first_item ['high']
high_price
# Out:
# '256.84'

# %%
# transfer data to dataframe
def transform_data (data):
    # extract values
    times_series = data['values']

    # covert to dataframe
    df = pd.DataFrame(times_series)

    # convert to proper data types
    df['datetime'] = pd.to_datetime(df['datetime'])

    df = df.astype({ 
        'open': 'float',
        'high':'float',
        'low': 'float', 
        'close': 'float',
        'volume': 'int'
    })

    return df

# %%
times_series = data['values']
times_series
# Out:
# [{'datetime': '2026-01-28 15:59:00',
#   'open': '256.83',
#   'high': '256.84',
#   'low': '256.67',
#   'close': '256.705',
#   'volume': '40964'},
#  {'datetime': '2026-01-28 15:58:00',
#   'open': '256.82',
#   'high': '256.84',
#   'low': '256.75',
#   'close': '256.8',
#   'volume': '29319'},
#  {'datetime': '2026-01-28 15:57:00',
#   'open': '256.7',
#   'high': '256.865',
#   'low': '256.7',
#   'close': '256.84',
#   'volume': '41873'},
#  {'datetime': '2026-01-28 15:56:00',
#   'open': '256.82',
#   'high': '256.89',
#   'low': '256.7',
#   'close': '256.7',
#   'volume': '41244'},
#  {'datetime': '2026-01-28 15:55:00',
#   'open': '256.84',
#   'high': '256.85',
#   'low': '256.57',
#   'close': '256.845',
#   'volume': '45419'}]

# %%
df = transform_data(data)

# %%
df
# Out:
#              datetime    open     high     low    close  volume
# 0 2026-01-28 15:59:00  256.83  256.840  256.67  256.705   40964
# 1 2026-01-28 15:58:00  256.82  256.840  256.75  256.800   29319
# 2 2026-01-28 15:57:00  256.70  256.865  256.70  256.840   41873
# 3 2026-01-28 15:56:00  256.82  256.890  256.70  256.700   41244
# 4 2026-01-28 15:55:00  256.84  256.850  256.57  256.845   45419

# %% [markdown]
# ##  Extract data for multiple symbols

# %%
symbols = [ 'AAPL', 'MSFT', 'GOOGL', 'AMZN']
all_data =[]

def fetch_data(symbol, api_key):
    url = f"https://api.twelvedata.com/time_series?symbol={symbol}&interval=1min&apikey={api_key}&outputsize=5"
    response = requests.get(url)
    response.raise_for_status() # this will raise an error for bad responses
    data = response.json()

    if data.get('status') != 'ok':
        raise ValueError(f'Error fetching data for {symbol}:{data.get("message", "Unknown error")}')

    return data

# %%
symbols = [ 'AAPL', 'MSFT', 'GOOGL', 'AMZN']

# %%
for symbol in symbols:
    data = fetch_data(symbol, api_key)
    df = transform_data(data)
    df['symbol'] = symbol
    all_data.append(df)

all_data
# Out:
# [             datetime       open       high        low      close  volume  \
#  0 2026-01-28 15:59:00  256.82999  256.84000  256.23999  256.44000  583999
#  1 2026-01-28 15:58:00  256.82001  256.84000  256.75000  256.82999  340210
#  2 2026-01-28 15:57:00  256.70001  256.87000  256.70000  256.80011  155119
#  3 2026-01-28 15:56:00  256.82001  256.89999  256.70000  256.70001  131854
#  4 2026-01-28 15:55:00  256.84000  256.89999  256.56000  256.81000  151476
#
#    symbol
#  0   AAPL
#  1   AAPL
#  2   AAPL
#  3   AAPL
#  4   AAPL  ,
#               datetime        open        high         low       close  volume  \
#  0 2026-01-28 15:59:00  483.015015  483.015015  481.329990  481.720000  522008
#  1 2026-01-28 15:58:00  483.049988  483.330000  482.799990  482.989990  324470
#  2 2026-01-28 15:57:00  482.079987  483.190000  482.059998  483.010101  201099
#  3 2026-01-28 15:56:00  482.029999  482.290010  481.890010  482.059998  150220
#  4 2026-01-28 15:55:00  481.200010  482.170010  481.100010  482.010010  129922
#
#    symbol
#  0   MSFT
#  1   MSFT
#  2   MSFT
#  3   MSFT
#  4   MSFT  ,
#               datetime       open       high     low      close  volume symbol
#  0 2026-01-28 15:59:00  336.51999  336.64001  335.84  336.14001  580245  GOOGL
#  1 2026-01-28 15:58:00  336.42001  336.54999  336.35  336.52499  240499  GOOGL
#  2 2026-01-28 15:57:00  336.32001  336.47501  336.17  336.42001  223564  GOOGL
#  3 2026-01-28 15:56:00  336.50000  336.51999  336.23  336.29001  187754  GOOGL
#  4 2026-01-28 15:55:00  336.78000  336.88000  335.73  336.48499  349896  GOOGL,
#               datetime       open       high     low       close   volume  \
#  0 2026-01-28 15:59:00  243.24001  243.30000  242.88  243.020004  9346405
#  1 2026-01-28 15:58:00  243.18500  243.27000  243.11  243.230000   172287
#  2 2026-01-28 15:57:00  243.19000  243.24001  243.11  243.179990   168826
#  3 2026-01-28 15:56:00  243.32001  243.35001  243.19  243.190000   112309
#  4 2026-01-28 15:55:00  243.58000  243.63000  243.00  243.304990   188554
#
#    symbol
#  0   AMZN
#  1   AMZN
#  2   AMZN
#  3   AMZN
#  4   AMZN  ]

# %%
# concat - joining or stacking all the dateframes together
all_df = pd.concat(all_data, ignore_index = True)

# %%
all_df
# Out:
#               datetime        open        high         low       close  \
# 0  2026-01-28 15:59:00  256.829990  256.840000  256.239990  256.440000
# 1  2026-01-28 15:58:00  256.820010  256.840000  256.750000  256.829990
# 2  2026-01-28 15:57:00  256.700010  256.870000  256.700000  256.800110
# 3  2026-01-28 15:56:00  256.820010  256.899990  256.700000  256.700010
# 4  2026-01-28 15:55:00  256.840000  256.899990  256.560000  256.810000
# 5  2026-01-28 15:59:00  483.015015  483.015015  481.329990  481.720000
# 6  2026-01-28 15:58:00  483.049988  483.330000  482.799990  482.989990
# 7  2026-01-28 15:57:00  482.079987  483.190000  482.059998  483.010101
# 8  2026-01-28 15:56:00  482.029999  482.290010  481.890010  482.059998
# 9  2026-01-28 15:55:00  481.200010  482.170010  481.100010  482.010010
# 10 2026-01-28 15:59:00  336.519990  336.640010  335.840000  336.140010
# 11 2026-01-28 15:58:00  336.420010  336.549990  336.350000  336.524990
# 12 2026-01-28 15:57:00  336.320010  336.475010  336.170000  336.420010
# 13 2026-01-28 15:56:00  336.500000  336.519990  336.230000  336.290010
# 14 2026-01-28 15:55:00  336.780000  336.880000  335.730000  336.484990
# 15 2026-01-28 15:59:00  243.240010  243.300000  242.880000  243.020004
# 16 2026-01-28 15:58:00  243.185000  243.270000  243.110000  243.230000
# 17 2026-01-28 15:57:00  243.190000  243.240010  243.110000  243.179990
# 18 2026-01-28 15:56:00  243.320010  243.350010  243.190000  243.190000
# 19 2026-01-28 15:55:00  243.580000  243.630000  243.000000  243.304990
#
#      volume symbol
# 0    583999   AAPL
# 1    340210   AAPL
# 2    155119   AAPL
# 3    131854   AAPL
# 4    151476   AAPL
# 5    522008   MSFT
# 6    324470   MSFT
# 7    201099   MSFT
# 8    150220   MSFT
# 9    129922   MSFT
# 10   580245  GOOGL
# 11   240499  GOOGL
# 12   223564  GOOGL
# 13   187754  GOOGL
# 14   349896  GOOGL
# 15  9346405   AMZN
# 16   172287   AMZN
# 17   168826   AMZN
# 18   112309   AMZN
# 19   188554   AMZN

# %% [markdown]
# ## Loading

# %%
load_dotenv()

DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')
DB_USER = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')

# %%
import os
print(os.getenv("DB_PASSWORD"))
# Out:
# 6574

# %%
print (DB_USER)
# Out:
# postgres

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\mumba\anaconda3\lib\site-packages (2.9.11)Note: you may need to restart the kernel to use updated packages.

# %%
# create database connection url
from sqlalchemy import create_engine
import psycopg2

db_url = f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}'
engine = create_engine(db_url)


# load datafram to postgres database
all_df.to_sql('stockPrices_data', engine, if_exists='append', index=False)

print('Data Loaded Successfully')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:620, in DefaultDialect.connect(self, *cargs, **cparams)
#     618 def connect(self, *cargs, **cparams):
#     619     # inherits the docstring from interfaces.Dialect.connect
# --> 620     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "appex_db" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[28], line 10
#       6 engine = create_engine(db_url)
#       9 # load datafram to postgres database
# ---> 10 all_df.to_sql('stockPrices_data', engine, if_exists='append', index=False)
#      12 print('Data Loaded Successfully')
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836 elif not isinstance(frame, DataFrame):
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
# --> 841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#    (...)
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\pandas\io\sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3276, in Engine.connect(self)
#    3253 def connect(self) -> Connection:
#    3254     """Return a new :class:`_engine.Connection` object.
#    3255
#    3256     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3273
#    3274     """
# -> 3276     return self._connection_cls(self)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2440, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2438 elif should_wrap:
#    2439     assert sqlalchemy_exception is not None
# -> 2440     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2441 else:
#    2442     assert exc_info[1] is not None
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3278 def raw_connection(self) -> PoolProxiedConnection:
#    3279     """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281     The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299     """
# -> 3300     return self.pool.connect()
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:620, in DefaultDialect.connect(self, *cargs, **cparams)
#     618 def connect(self, *cargs, **cparams):
#     619     # inherits the docstring from interfaces.Dialect.connect
# --> 620     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\mumba\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "appex_db" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
